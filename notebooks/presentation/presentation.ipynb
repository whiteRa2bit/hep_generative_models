# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tqdm
import torch
from torch.autograd import Variable

from generation.dataset.data_utils import get_detector_training_data
from generation.dataset.signals_dataset import SignalsDataset

# %%
signals = [get_detector_training_data(detector) for detector in range(9)]
signals = np.array(signals)

# %%
signals.shape
# Out:
# (9, 19900, 2048)

# %%
plt.plot(signals[0][100])
plt.plot(signals[1][100])

# %%
dataset = SignalsDataset(0, 1024)
# Out:
# /datadrive/pafakanov/hse/hep_generative_models/generation/dataset/signals_dataset.py:54: RuntimeWarning: invalid value encountered in true_divide
#   data = (data - min_values[:, None]) / (max_values - min_values)[:, None]

# %%
plt.title("Scaled signal")
plt.plot(dataset.signals[0])
plt.show()
plt.title("Mean signal")
mean_signal = np.mean(dataset.signals, axis=0)
plt.plot(mean_signal)
plt.show()
plt.title("Noise")
plt.plot(dataset.signals[0] - mean_signal)
plt.show()

# %%
from generation.dataset.data_utils import postprocess_signal

# %%
# post_signal = postprocess_signal(dataset.signals[0])
plt.title("Before processing")
plt.plot(dataset.signals[0])
plt.show()
plt.title("After processing")
plt.plot(post_signal)
plt.axvline(x=85, color='red')
plt.plot([85], [47000], marker='o', markersize=7, color="red")
plt.legend(['Signal', 'Half of amplitude'])
plt.show()
