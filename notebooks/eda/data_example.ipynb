# %%
import pandas as pd
import tqdm
import matplotlib.pyplot as plt
import numpy as np
from generation.data.data_preparation import generate_single_detector_output, get_detector_df,\
                                                generate_detector_output, postprocess_step_energies

# %%
DETECTOR = 1
EVENT = 0

df = pd.read_pickle("/home/pafakanov/data/hep_data/particles.pkl")

# %% [markdown]
# ##### All events

# %%
detector_df = get_detector_df(df, detector=DETECTOR)

# %%
signal_output = generate_single_detector_output(detector_df, steps_num=1024, sample_coef=1/9)
processed_signal_output = postprocess_step_energies(signal_output)
f, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].set_title("Before photodetector")
ax[0].plot(signal_output)
ax[1].set_title("After photodetector")
ax[1].plot(processed_signal_output)
plt.show()

# %% [markdown]
# ##### Events separately

# %%
signal_output = generate_single_detector_output(detector_event_df, steps_num=1024)
processed_signal_output = postprocess_step_energies(signal_output)
f, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].set_title("Before photodetector")
ax[0].plot(signal_output)
ax[1].set_title("After photodetector")
ax[1].plot(processed_signal_output)
plt.show()
