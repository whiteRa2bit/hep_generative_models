# %%
import pandas as pd
import tqdm
import matplotlib.pyplot as plt
import numpy as np
from generation.data.data_preparation import generate_detector_event_output, postprocess_output

# %%
df = pd.read_pickle("/home/pafakanov/data/hep_data/particles.pkl")

# %%
signal_output = generate_detector_event_output(df, detector=0, event=0, steps_num=1024)
processed_signal_output = postprocess_output(signal_output)

# %%
f, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].set_title("Before photodetector")
ax[0].plot(signal_output)
ax[1].set_title("After photodetector")
ax[1].plot(processed_signal_output)
plt.show()
