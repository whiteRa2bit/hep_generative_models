# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from generation.data.data_simulation import Nakagami

# %%
SAMPLE_SIZE = 1000
Q_LOWER = 0.001
Q_UPPER = 0.999

nakagami = Nakagami(SAMPLE_SIZE, Q_LOWER, Q_UPPER)

# %%
NU_MIN = 0.9
NU_MAX = 1.2
NU_STEP = 0.005

nu_values = np.arange(NU_MIN, NU_MAX, NU_STEP)
nakagami_data = nakagami.get_nakagami_data(nu_values)

# %%
for sample in nakagami_data:
    plt.plot(sample)
plt.show()
